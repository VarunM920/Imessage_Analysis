# %%
import pandas as pd
df = pd.read_csv('Reaction.csv')
df

###IMPORTANT:
#Chinmaya's name requires two spaces in between the names: Chinmaya  Joshi
# Out:
#        associated_message_type        nameofreactor        nameofreactee
# 0                         2000      Manish Bhardvaj     Pranav Nelakonda
# 1                         2004     Anish Aravapalli           Ishan Brar
# 2                         2004          Neil Sharma     Anish Aravapalli
# 3                         2000          Neil Sharma      Manish Bhardvaj
# 4                         2001          Rohan Khera           Ishan Brar
# 5                         2003       Shreyas Sharma      Manish Bhardvaj
# 6                         2001    Abhinav Dommaraju     Pranav Nelakonda
# 7                         2004      Akhil Balireddy      Manish Bhardvaj
# 8                         2004      Manish Bhardvaj         Nick Shivani
# 9                         2004         Nick Shivani      Manish Bhardvaj
# 10                        2003       Varun Mehrotra  Nathan Govindarajan
# 11                        2003        Parsia Benham     Pranav Nelakonda
# ...

# %%
#Creates a dictionary wiht all the tallies of all the reactions for all participants
participants = {'Varun Mehrotra':[0,0,0,0,0,0], 'Neil Sharma':[0,0,0,0,0,0], 'Shreyas Sharma':[0,0,0,0,0,0], 
                'Nick Shivani':[0,0,0,0,0,0], 'Rohan Khera':[0,0,0,0,0,0], 'Paritosh Suri':[0,0,0,0,0,0], 
                'Jack Butler':[0,0,0,0,0,0], 'Nathaniel Wang':[0,0,0,0,0,0], 'Ishan Brar':[0,0,0,0,0,0], 
                'Manish Bhardvaj':[0,0,0,0,0,0], 'Nathan Govindarajan':[0,0,0,0,0,0], 'Jason Trehan':[0,0,0,0,0,0], 
                'Iram Choudhury':[0,0,0,0,0,0], 'Anirudh Rayanki':[0,0,0,0,0,0], 'Anish Aravapalli':[0,0,0,0,0,0], 
                'Shaan Bhandari':[0,0,0,0,0,0], 'Pranav Nelakonda':[0,0,0,0,0,0], 'Parsia Benham':[0,0,0,0,0,0], 
                'Chinmaya  Joshi':[0,0,0,0,0,0],'Akhil Balireddy':[0,0,0,0,0,0], 'Abhinav Dommaraju':[0,0,0,0,0,0]}
#Loops through every reaction in table
for i in df.index:
    #Looks at reaction type and appends it to the appropriate reaction to appropriate person
    if df.iloc[i,0] == 2000:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name][0] += 1
    if df.iloc[i,0] == 2001:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name][1] += 1
    if df.iloc[i,0] == 2002:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name][2] += 1
    if df.iloc[i,0] == 2003:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name][3] += 1
    if df.iloc[i,0] == 2004:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name][4] += 1
                
    if df.iloc[i,0] == 2005:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name][5] += 1
        
print(participants)

#Create dataframe from data
df_getsreaction = pd.DataFrame(participants, index = ['Love', 'Like', 'Dislike', 'Laughed', 'Emphasized', 'Questioned'])
df_getsreaction = df_getsreaction.transpose()
#Orders data for whichever reaction
df_getsreaction = df_getsreaction.sort_values('Love', ascending = False)
df_getsreaction
# Out:
# {'Varun Mehrotra': [88, 143, 38, 389, 131, 18], 'Neil Sharma': [33, 46, 23, 120, 55, 5], 'Shreyas Sharma': [120, 157, 68, 474, 300, 20], 'Nick Shivani': [135, 207, 78, 559, 386, 43], 'Rohan Khera': [34, 35, 19, 229, 44, 8], 'Paritosh Suri': [1, 0, 0, 13, 2, 0], 'Jack Butler': [0, 1, 0, 0, 0, 0], 'Nathaniel Wang': [24, 54, 8, 240, 140, 8], 'Ishan Brar': [60, 135, 65, 863, 172, 25], 'Manish Bhardvaj': [101, 256, 92, 1128, 559, 34], 'Nathan Govindarajan': [30, 51, 24, 164, 57, 3], 'Jason Trehan': [55, 83, 20, 142, 68, 7], 'Iram Choudhury': [12, 34, 10, 186, 68, 6], 'Anirudh Rayanki': [22, 14, 17, 105, 32, 3], 'Anish Aravapalli': [12, 59, 24, 121, 46, 15], 'Shaan Bhandari': [1, 2, 0, 10, 1, 0], 'Pranav Nelakonda': [76, 146, 90, 426, 313, 34], 'Parsia Benham': [50, 64, 33, 273, 80, 22], 'Chinmaya  Joshi': [1, 1, 0, 4, 4, 0], 'Akhil Balireddy': [16, 39, 13, 47, 30, 2], 'Abhinav Dommaraju': [33, 41, 9, 94, 67, 4]}
#                      Love  Like  Dislike  Laughed  Emphasized  Questioned
# ...

# %%
participants = {'Varun Mehrotra':[0,0,0,0,0,0], 'Neil Sharma':[0,0,0,0,0,0], 'Shreyas Sharma':[0,0,0,0,0,0], 
                'Nick Shivani':[0,0,0,0,0,0], 'Rohan Khera':[0,0,0,0,0,0], 'Paritosh Suri':[0,0,0,0,0,0], 
                'Jack Butler':[0,0,0,0,0,0], 'Nathaniel Wang':[0,0,0,0,0,0], 'Ishan Brar':[0,0,0,0,0,0], 
                'Manish Bhardvaj':[0,0,0,0,0,0], 'Nathan Govindarajan':[0,0,0,0,0,0], 'Jason Trehan':[0,0,0,0,0,0], 
                'Iram Choudhury':[0,0,0,0,0,0], 'Anirudh Rayanki':[0,0,0,0,0,0], 'Anish Aravapalli':[0,0,0,0,0,0], 
                'Shaan Bhandari':[0,0,0,0,0,0], 'Pranav Nelakonda':[0,0,0,0,0,0], 'Parsia Benham':[0,0,0,0,0,0], 
                'Chinmaya  Joshi':[0,0,0,0,0,0],'Akhil Balireddy':[0,0,0,0,0,0], 'Abhinav Dommaraju':[0,0,0,0,0,0]}
for i in df.index:
    if df.iloc[i,0] == 2000:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name][0] += 1
    if df.iloc[i,0] == 2001:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name][1] += 1
    if df.iloc[i,0] == 2002:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name][2] += 1
    if df.iloc[i,0] == 2003:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name][3] += 1
    if df.iloc[i,0] == 2004:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name][4] += 1
                
    if df.iloc[i,0] == 2005:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name][5] += 1
        
print(participants)

df_reacts = pd.DataFrame(participants, index = ['Love', 'Like', 'Dislike', 'Laughed', 'Emphasized', 'Questioned'])
df_reacts = df_reacts.transpose()
df_reacts = df_reacts.sort_values('Love', ascending = False)
df_reacts.to_csv('reacts.csv')
df_reacts
# Out:
# {'Varun Mehrotra': [45, 36, 15, 479, 76, 25], 'Neil Sharma': [114, 80, 33, 961, 153, 21], 'Shreyas Sharma': [109, 126, 51, 359, 163, 6], 'Nick Shivani': [83, 341, 80, 1040, 642, 28], 'Rohan Khera': [29, 71, 7, 87, 19, 4], 'Paritosh Suri': [0, 2, 4, 10, 2, 0], 'Jack Butler': [0, 0, 1, 0, 1, 0], 'Nathaniel Wang': [10, 10, 3, 65, 28, 0], 'Ishan Brar': [54, 74, 12, 309, 174, 21], 'Manish Bhardvaj': [183, 292, 116, 578, 455, 55], 'Nathan Govindarajan': [54, 90, 44, 135, 77, 5], 'Jason Trehan': [31, 171, 40, 342, 265, 18], 'Iram Choudhury': [14, 21, 4, 109, 32, 8], 'Anirudh Rayanki': [28, 48, 12, 126, 25, 8], 'Anish Aravapalli': [46, 31, 57, 490, 213, 13], 'Shaan Bhandari': [1, 0, 3, 4, 9, 0], 'Pranav Nelakonda': [27, 75, 40, 397, 54, 22], 'Parsia Benham': [12, 41, 31, 53, 14, 9], 'Chinmaya  Joshi': [4, 1, 2, 4, 3, 1], 'Akhil Balireddy': [51, 78, 81, 148, 122, 15], 'Abhinav Dommaraju': [38, 9, 6, 57, 45, 1]}
#                      Love  Like  Dislike  Laughed  Emphasized  Questioned
# ...

# %%
sort_by = input('Enter category to sort by:')
df_reacts = df_reacts.sort_values(sort_by, ascending = False)
df_reacts
# Out:
# Enter category to sort by:Love
#                      Love  Like  Dislike  Laughed  Emphasized  Questioned
# Manish Bhardvaj       183   292      116      578         455          55
# Neil Sharma           114    80       33      961         153          21
# Shreyas Sharma        109   126       51      359         163           6
# Nick Shivani           83   341       80     1040         642          28
# Ishan Brar             54    74       12      309         174          21
# Nathan Govindarajan    54    90       44      135          77           5
# Akhil Balireddy        51    78       81      148         122          15
# Anish Aravapalli       46    31       57      490         213          13
# Varun Mehrotra         45    36       15      479          76          25
# Jason Trehan           31   171       40      342         265          18
# Rohan Khera            29    71        7       87          19           4
# ...

# %%
participants = {'Varun Mehrotra':0, 'Neil Sharma':0, 'Shreyas Sharma':0, 'Nick Shivani':0, 'Rohan Khera':0, 'Paritosh Suri':0, 'Jack Butler':0,
               'Nathaniel Wang':0, 'Ishan Brar':0, 'Manish Bhardvaj':0, 'Nathan Govindarajan':0, 'Jason Trehan':0, 'Iram Choudhury':0,
               'Anirudh Rayanki':0, 'Anish Aravapalli':0, 'Shaan Bhandari':0, 'Pranav Nelakonda':0, 'Parsia Benham':0, 'Chinmaya  Joshi':0,
               'Akhil Balireddy':0, 'Abhinav Dommaraju':0}

df_total = pd.read_csv('total_text_data.csv')
for i in df_total.index:
    for key in participants.keys():
        if df_total.iloc[i,0] == key:
            participants[key] += 1

print(participants)
print(df_getsreaction.iloc[0,0])
newcol = []
for i in df_getsreaction.index:
    for key in participants.keys():
        if key == i:
            newcol.append(participants[key])
    
print(newcol)
df_getsreaction['Total Texts'] = newcol
df_total = pd.DataFrame(participants, index = ['Total Texts'])
df_total = df_total.transpose()
df_total = df_total.sort_values('Total Texts', ascending = False)
df_total
# Out:
# {'Varun Mehrotra': 3744, 'Neil Sharma': 1742, 'Shreyas Sharma': 10611, 'Nick Shivani': 11484, 'Rohan Khera': 797, 'Paritosh Suri': 36, 'Jack Butler': 10, 'Nathaniel Wang': 1720, 'Ishan Brar': 5355, 'Manish Bhardvaj': 24318, 'Nathan Govindarajan': 1249, 'Jason Trehan': 2361, 'Iram Choudhury': 1634, 'Anirudh Rayanki': 1638, 'Anish Aravapalli': 2875, 'Shaan Bhandari': 69, 'Pranav Nelakonda': 5332, 'Parsia Benham': 5254, 'Chinmaya  Joshi': 89, 'Akhil Balireddy': 1756, 'Abhinav Dommaraju': 1951}
# 135
# [11484, 10611, 24318, 3744, 5332, 5355, 2361, 5254, 797, 1742, 1951, 1249, 1720, 1638, 1756, 1634, 2875, 69, 36, 89, 10]
#                      Total Texts
# Manish Bhardvaj            24318
# Nick Shivani               11484
# Shreyas Sharma             10611
# Ishan Brar                  5355
# Pranav Nelakonda            5332
# Parsia Benham               5254
# Varun Mehrotra              3744
# Anish Aravapalli            2875
# Jason Trehan                2361
# ...

# %%
df_getsreaction.to_csv('getsreaction.csv')
df_getsreaction
# Out:
#                      Love  Like  Dislike  Laughed  Emphasized  Questioned  \
# Nick Shivani          135   207       78      559         386          43
# Shreyas Sharma        120   157       68      474         300          20
# Manish Bhardvaj       101   256       92     1128         559          34
# Varun Mehrotra         88   143       38      389         131          18
# Pranav Nelakonda       76   146       90      426         313          34
# Ishan Brar             60   135       65      863         172          25
# Jason Trehan           55    83       20      142          68           7
# Parsia Benham          50    64       33      273          80          22
# Rohan Khera            34    35       19      229          44           8
# Neil Sharma            33    46       23      120          55           5
# Abhinav Dommaraju      33    41        9       94          67           4
# Nathan Govindarajan    30    51       24      164          57           3
# ...

# %%
sort_by = input('Enter category to sort by:')
df_getsreaction = df_getsreaction.sort_values(sort_by, ascending = False)
df_getsreaction
# Out:
# Enter category to sort by:s
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-4d8a64a41ff5> in <module>
#       1 sort_by = input('Enter category to sort by:')
# ----> 2 df_getsreaction = df_getsreaction.sort_values(sort_by, ascending = False)
#       3 df_getsreaction
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
# ...

# %%
df_ratio = df_getsreaction.copy(deep = True)
df_ratio
print(df_ratio.iloc[0,6])
for i in range(0, len(df_ratio.index)):
    for j in range(0,6):
        df_ratio.iloc[i,j] /= df_ratio.iloc[i,6]
df_ratio.to_csv('reaction_ratio.csv')
df_ratio
# Out:
# 11484
#                          Love      Like   Dislike   Laughed  Emphasized  \
# Nick Shivani         0.011755  0.018025  0.006792  0.048676    0.033612
# Shreyas Sharma       0.011309  0.014796  0.006408  0.044671    0.028273
# Manish Bhardvaj      0.004153  0.010527  0.003783  0.046385    0.022987
# Varun Mehrotra       0.023504  0.038194  0.010150  0.103900    0.034989
# Pranav Nelakonda     0.014254  0.027382  0.016879  0.079895    0.058702
# Ishan Brar           0.011204  0.025210  0.012138  0.161158    0.032120
# Jason Trehan         0.023295  0.035155  0.008471  0.060144    0.028801
# Parsia Benham        0.009517  0.012181  0.006281  0.051960    0.015226
# Rohan Khera          0.042660  0.043915  0.023839  0.287327    0.055207
# Neil Sharma          0.018944  0.026406  0.013203  0.068886    0.031573
# Abhinav Dommaraju    0.016914  0.021015  0.004613  0.048180    0.034341
# Nathan Govindarajan  0.024019  0.040833  0.019215  0.131305    0.045637
# ...

# %%
sort_by = input('Enter category to sort by:')
df_ratio = df_ratio.sort_values(sort_by, ascending = False)
df_ratio
# Out:
# Enter category to sort by:Questioned
#                          Love      Like   Dislike   Laughed  Emphasized  \
# Rohan Khera          0.042660  0.043915  0.023839  0.287327    0.055207
# Pranav Nelakonda     0.014254  0.027382  0.016879  0.079895    0.058702
# Anish Aravapalli     0.004174  0.020522  0.008348  0.042087    0.016000
# Varun Mehrotra       0.023504  0.038194  0.010150  0.103900    0.034989
# Ishan Brar           0.011204  0.025210  0.012138  0.161158    0.032120
# Nathaniel Wang       0.013953  0.031395  0.004651  0.139535    0.081395
# Parsia Benham        0.009517  0.012181  0.006281  0.051960    0.015226
# Nick Shivani         0.011755  0.018025  0.006792  0.048676    0.033612
# Iram Choudhury       0.007344  0.020808  0.006120  0.113831    0.041616
# Jason Trehan         0.023295  0.035155  0.008471  0.060144    0.028801
# Neil Sharma          0.018944  0.026406  0.013203  0.068886    0.031573
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sum = 0
name = input("Enter name you want to see distribution of:")
index = 0
distribution = []
for i in df_reacts.index:
    if i == name:
        for j in range(0,6):
            sum += df_reacts.iloc[index,j]
        for j in range(0,6):
            distribution.append(df_reacts.iloc[index,j]/sum)
    index += 1
print(sum)
print(distribution)

reactions = ['Love', 'Like', 'Dislike', 'Laughed', 'Emphasized', 'Questioned']


plt.bar(reactions,distribution)
plt.title(name + ' Distribution')
plt.xlabel('Type of Reaction')
plt.ylabel('Probability')
plt.show()
# Out:
# Enter name you want to see distribution of:Varun Mehrotra
# 676
# [0.06656804733727811, 0.05325443786982249, 0.022189349112426034, 0.7085798816568047, 0.11242603550295859, 0.03698224852071006]

# %%
participants = {'Varun Mehrotra':0, 'Neil Sharma':0, 'Shreyas Sharma':0, 'Nick Shivani':0, 'Rohan Khera':0, 'Paritosh Suri':0, 'Jack Butler':0,
               'Nathaniel Wang':0, 'Ishan Brar':0, 'Manish Bhardvaj':0, 'Nathan Govindarajan':0, 'Jason Trehan':0, 'Iram Choudhury':0,
               'Anirudh Rayanki':0, 'Anish Aravapalli':0, 'Shaan Bhandari':0, 'Pranav Nelakonda':0, 'Parsia Benham':0, 'Chinmaya  Joshi':0,
               'Akhil Balireddy':0}
count = 0
for i in df.index:
    if df.iloc[i,0] == 2000:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name] += 1
        
print(participants)

df_getslove = pd.DataFrame(participants, index = [1])
df_getslove = df_getslove.transpose()
df_getslove = df_getslove.sort_values(1, ascending = False)
df_getslove
# Out:
# {'Varun Mehrotra': 88, 'Neil Sharma': 33, 'Shreyas Sharma': 120, 'Nick Shivani': 135, 'Rohan Khera': 34, 'Paritosh Suri': 1, 'Jack Butler': 0, 'Nathaniel Wang': 24, 'Ishan Brar': 60, 'Manish Bhardvaj': 101, 'Nathan Govindarajan': 30, 'Jason Trehan': 55, 'Iram Choudhury': 12, 'Anirudh Rayanki': 22, 'Anish Aravapalli': 12, 'Shaan Bhandari': 1, 'Pranav Nelakonda': 76, 'Parsia Benham': 50, 'Chinmaya  Joshi': 1, 'Akhil Balireddy': 16}
#                        1
# Nick Shivani         135
# Shreyas Sharma       120
# Manish Bhardvaj      101
# Varun Mehrotra        88
# Pranav Nelakonda      76
# Ishan Brar            60
# Jason Trehan          55
# Parsia Benham         50
# Rohan Khera           34
# Neil Sharma           33
# Nathan Govindarajan   30
# Nathaniel Wang        24
# Anirudh Rayanki       22
# Akhil Balireddy       16
# Iram Choudhury        12
# Anish Aravapalli      12
# Shaan Bhandari         1
# Paritosh Suri          1
# Chinmaya  Joshi        1
# ...

# %%
participants = {'Varun Mehrotra':0, 'Neil Sharma':0, 'Shreyas Sharma':0, 'Nick Shivani':0, 'Rohan Khera':0, 'Paritosh Suri':0, 'Jack Butler':0,
               'Nathaniel Wang':0, 'Ishan Brar':0, 'Manish Bhardvaj':0, 'Nathan Govindarajan':0, 'Jason Trehan':0, 'Iram Choudhury':0,
               'Anirudh Rayanki':0, 'Anish Aravapalli':0, 'Shaan Bhandari':0, 'Pranav Nelakonda':0, 'Parsia Benham':0, 'Chinmaya  Joshi':0,
               'Akhil Balireddy':0}
count = 0
for i in df.index:
    if df.iloc[i,0] == 2000:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name] += 1
        
print(participants)

df_love = pd.DataFrame(participants, index = [1])
df_love = df_love.transpose()
df_love = df_love.sort_values(1, ascending = False)
df_love
# Out:
# {'Varun Mehrotra': 45, 'Neil Sharma': 114, 'Shreyas Sharma': 109, 'Nick Shivani': 83, 'Rohan Khera': 29, 'Paritosh Suri': 0, 'Jack Butler': 0, 'Nathaniel Wang': 10, 'Ishan Brar': 54, 'Manish Bhardvaj': 183, 'Nathan Govindarajan': 54, 'Jason Trehan': 31, 'Iram Choudhury': 14, 'Anirudh Rayanki': 28, 'Anish Aravapalli': 46, 'Shaan Bhandari': 1, 'Pranav Nelakonda': 27, 'Parsia Benham': 12, 'Chinmaya  Joshi': 4, 'Akhil Balireddy': 51}
#                        1
# Manish Bhardvaj      183
# Neil Sharma          114
# Shreyas Sharma       109
# Nick Shivani          83
# Nathan Govindarajan   54
# Ishan Brar            54
# Akhil Balireddy       51
# Anish Aravapalli      46
# Varun Mehrotra        45
# Jason Trehan          31
# Rohan Khera           29
# Anirudh Rayanki       28
# Pranav Nelakonda      27
# Iram Choudhury        14
# Parsia Benham         12
# Nathaniel Wang        10
# Chinmaya  Joshi        4
# Shaan Bhandari         1
# Jack Butler            0
# ...

# %%
participants = {'Varun Mehrotra':0, 'Neil Sharma':0, 'Shreyas Sharma':0, 'Nick Shivani':0, 'Rohan Khera':0, 'Paritosh Suri':0, 'Jack Butler':0,
               'Nathaniel Wang':0, 'Ishan Brar':0, 'Manish Bhardvaj':0, 'Nathan Govindarajan':0, 'Jason Trehan':0, 'Iram Choudhury':0,
               'Anirudh Rayanki':0, 'Anish Aravapalli':0, 'Shaan Bhandari':0, 'Pranav Nelakonda':0, 'Parsia Benham':0, 'Chinmaya  Joshi':0,
               'Akhil Balireddy':0}
count = 0
for i in df.index:
    if df.iloc[i,0] == 2001:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name] += 1
        
print(participants)

df_getslike = pd.DataFrame(participants, index = [1])
df_getslike = df_getslike.transpose()
df_getslike = df_getslike.sort_values(1, ascending = False)
df_getslike
# Out:
# {'Varun Mehrotra': 143, 'Neil Sharma': 46, 'Shreyas Sharma': 157, 'Nick Shivani': 207, 'Rohan Khera': 35, 'Paritosh Suri': 0, 'Jack Butler': 1, 'Nathaniel Wang': 54, 'Ishan Brar': 135, 'Manish Bhardvaj': 256, 'Nathan Govindarajan': 51, 'Jason Trehan': 83, 'Iram Choudhury': 34, 'Anirudh Rayanki': 14, 'Anish Aravapalli': 59, 'Shaan Bhandari': 2, 'Pranav Nelakonda': 146, 'Parsia Benham': 64, 'Chinmaya  Joshi': 1, 'Akhil Balireddy': 39}
#                        1
# Manish Bhardvaj      256
# Nick Shivani         207
# Shreyas Sharma       157
# Pranav Nelakonda     146
# Varun Mehrotra       143
# Ishan Brar           135
# Jason Trehan          83
# Parsia Benham         64
# Anish Aravapalli      59
# Nathaniel Wang        54
# Nathan Govindarajan   51
# Neil Sharma           46
# Akhil Balireddy       39
# Rohan Khera           35
# Iram Choudhury        34
# Anirudh Rayanki       14
# Shaan Bhandari         2
# Jack Butler            1
# Chinmaya  Joshi        1
# ...

# %%
participants = {'Varun Mehrotra':0, 'Neil Sharma':0, 'Shreyas Sharma':0, 'Nick Shivani':0, 'Rohan Khera':0, 'Paritosh Suri':0, 'Jack Butler':0,
               'Nathaniel Wang':0, 'Ishan Brar':0, 'Manish Bhardvaj':0, 'Nathan Govindarajan':0, 'Jason Trehan':0, 'Iram Choudhury':0,
               'Anirudh Rayanki':0, 'Anish Aravapalli':0, 'Shaan Bhandari':0, 'Pranav Nelakonda':0, 'Parsia Benham':0, 'Chinmaya  Joshi':0,
               'Akhil Balireddy':0}
count = 0
for i in df.index:
    if df.iloc[i,0] == 2001:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name] += 1
        
print(participants)

df_likes = pd.DataFrame(participants, index = [1])
df_likes = df_likes.transpose()
df_likes = df_likes.sort_values(1, ascending = False)
df_likes
# Out:
# {'Varun Mehrotra': 36, 'Neil Sharma': 80, 'Shreyas Sharma': 126, 'Nick Shivani': 341, 'Rohan Khera': 71, 'Paritosh Suri': 2, 'Jack Butler': 0, 'Nathaniel Wang': 10, 'Ishan Brar': 74, 'Manish Bhardvaj': 292, 'Nathan Govindarajan': 90, 'Jason Trehan': 171, 'Iram Choudhury': 21, 'Anirudh Rayanki': 48, 'Anish Aravapalli': 31, 'Shaan Bhandari': 0, 'Pranav Nelakonda': 75, 'Parsia Benham': 41, 'Chinmaya  Joshi': 1, 'Akhil Balireddy': 78}
#                        1
# Nick Shivani         341
# Manish Bhardvaj      292
# Jason Trehan         171
# Shreyas Sharma       126
# Nathan Govindarajan   90
# Neil Sharma           80
# Akhil Balireddy       78
# Pranav Nelakonda      75
# Ishan Brar            74
# Rohan Khera           71
# Anirudh Rayanki       48
# Parsia Benham         41
# Varun Mehrotra        36
# Anish Aravapalli      31
# Iram Choudhury        21
# Nathaniel Wang        10
# Paritosh Suri          2
# Chinmaya  Joshi        1
# Jack Butler            0
# ...

# %%
participants = {'Varun Mehrotra':0, 'Neil Sharma':0, 'Shreyas Sharma':0, 'Nick Shivani':0, 'Rohan Khera':0, 'Paritosh Suri':0, 'Jack Butler':0,
               'Nathaniel Wang':0, 'Ishan Brar':0, 'Manish Bhardvaj':0, 'Nathan Govindarajan':0, 'Jason Trehan':0, 'Iram Choudhury':0,
               'Anirudh Rayanki':0, 'Anish Aravapalli':0, 'Shaan Bhandari':0, 'Pranav Nelakonda':0, 'Parsia Benham':0, 'Chinmaya  Joshi':0,
               'Akhil Balireddy':0}
count = 0
for i in df.index:
    if df.iloc[i,0] == 2002:
        for name in participants.keys():
            if df.iloc[i,2] == name:
                participants[name] += 1
        
print(participants)

df_getsdislike = pd.DataFrame(participants, index = [1])
df_getsdislike = df_getsdislike.transpose()
df_getsdislike = df_getsdislike.sort_values(1, ascending = False)
df_getsdislike
# Out:
# {'Varun Mehrotra': 38, 'Neil Sharma': 23, 'Shreyas Sharma': 68, 'Nick Shivani': 78, 'Rohan Khera': 19, 'Paritosh Suri': 0, 'Jack Butler': 0, 'Nathaniel Wang': 8, 'Ishan Brar': 65, 'Manish Bhardvaj': 92, 'Nathan Govindarajan': 24, 'Jason Trehan': 20, 'Iram Choudhury': 10, 'Anirudh Rayanki': 17, 'Anish Aravapalli': 24, 'Shaan Bhandari': 0, 'Pranav Nelakonda': 90, 'Parsia Benham': 33, 'Chinmaya  Joshi': 0, 'Akhil Balireddy': 13}
#                       1
# Manish Bhardvaj      92
# Pranav Nelakonda     90
# Nick Shivani         78
# Shreyas Sharma       68
# Ishan Brar           65
# Varun Mehrotra       38
# Parsia Benham        33
# Anish Aravapalli     24
# Nathan Govindarajan  24
# Neil Sharma          23
# Jason Trehan         20
# Rohan Khera          19
# Anirudh Rayanki      17
# Akhil Balireddy      13
# Iram Choudhury       10
# Nathaniel Wang        8
# Jack Butler           0
# Shaan Bhandari        0
# Paritosh Suri         0
# Chinmaya  Joshi       0

# %%
participants = {'Varun Mehrotra':0, 'Neil Sharma':0, 'Shreyas Sharma':0, 'Nick Shivani':0, 'Rohan Khera':0, 'Paritosh Suri':0, 'Jack Butler':0,
               'Nathaniel Wang':0, 'Ishan Brar':0, 'Manish Bhardvaj':0, 'Nathan Govindarajan':0, 'Jason Trehan':0, 'Iram Choudhury':0,
               'Anirudh Rayanki':0, 'Anish Aravapalli':0, 'Shaan Bhandari':0, 'Pranav Nelakonda':0, 'Parsia Benham':0, 'Chinmaya  Joshi':0,
               'Akhil Balireddy':0}
count = 0
for i in df.index:
    if df.iloc[i,0] == 2002:
        for name in participants.keys():
            if df.iloc[i,1] == name:
                participants[name] += 1
        
print(participants)

df_dislikes = pd.DataFrame(participants, index = [1])
df_dislikes = df_getsdislike.transpose()
df_dislikes = df_getsdislike.sort_values(1, ascending = False)
df_dislikes
